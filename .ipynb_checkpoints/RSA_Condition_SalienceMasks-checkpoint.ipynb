# %%
# %matplotlib inline

import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltools.data import Brain_Data, Adjacency
from nltools.mask import expand_mask
from nltools.stats import fdr, threshold, fisher_r_to_z, one_sample_permutation
from sklearn.metrics import pairwise_distances
from nilearn.plotting import plot_glass_brain, plot_stat_map
import nilearn.plotting as plotting
from nilearn import datasets
from nilearn import plotting

# %%
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr50-2mm')
insula_idx = 2
acc_idx = 29

# %%
parcellations = Brain_Data(dataset.maps)
expanded_parcellations = expand_mask(parcellations)
plot_glass_brain(expanded_parcellations[3].to_nifti())
plot_glass_brain(expanded_parcellations[acc_idx].to_nifti())

# %%
expanded_parcellations[insula_idx]
# Out:
# nltools.data.brain_data.Brain_Data(data=(238955,), Y=0, X=(0, 0), mask=MNI152_T1_2mm_brain_mask.nii.gz, output_file=[])

# %%
data_dir = 'first_level_conditiononly_1022519/'
sub_list = glob.glob(os.path.join(data_dir,'*'))

mask = expanded_parcellations[acc_idx]


distance = []
for sub in sub_list[:]:
    print(sub)
    # only get betas of relevance
    file_list = glob.glob(os.path.join(sub, '*con*'))
    file_list.append(glob.glob(os.path.join(sub, '*prime*'))[0])
    print(file_list)
    #reordered list
    #load brain data
    print('loading brains')
    beta = Brain_Data(file_list)
    #get labels
    condition_labels = [file[40:50] for file in file_list]
    #calculate distance 
    print('calculating_distance')
    distance_subject = beta.apply_mask(mask).distance(method='correlation')
    distance_subject.labels = condition_labels
    #append
    distance.append(distance_subject)
    
summed_scores = distance[-1].data
for i in range(len(distance)-1):
    summed_scores += distance[i].data
    
averaged_scores = summed_scores/len(distance)

avg_adjacency = Adjacency(averaged_scores)
avg_adjacency.labels = condition_labels
fig = avg_adjacency.plot(vmax=2, vmin=0)
# Out:
# first_level_conditiononly_1022519/cp001
# ['first_level_conditiononly_1022519/cp001/congruent.nii.gz', 'first_level_conditiononly_1022519/cp001/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp001/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp002
# ['first_level_conditiononly_1022519/cp002/congruent.nii.gz', 'first_level_conditiononly_1022519/cp002/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp002/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp003
# ['first_level_conditiononly_1022519/cp003/congruent.nii.gz', 'first_level_conditiononly_1022519/cp003/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp003/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp004
# ['first_level_conditiononly_1022519/cp004/congruent.nii.gz', 'first_level_conditiononly_1022519/cp004/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp004/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp005
# ['first_level_conditiononly_1022519/cp005/congruent.nii.gz', 'first_level_conditiononly_1022519/cp005/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp005/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp006
# ['first_level_conditiononly_1022519/cp006/congruent.nii.gz', 'first_level_conditiononly_1022519/cp006/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp006/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp007
# ['first_level_conditiononly_1022519/cp007/congruent.nii.gz', 'first_level_conditiononly_1022519/cp007/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp007/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp008
# ['first_level_conditiononly_1022519/cp008/congruent.nii.gz', 'first_level_conditiononly_1022519/cp008/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp008/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp009
# ['first_level_conditiononly_1022519/cp009/congruent.nii.gz', 'first_level_conditiononly_1022519/cp009/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp009/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp010
# ['first_level_conditiononly_1022519/cp010/congruent.nii.gz', 'first_level_conditiononly_1022519/cp010/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp010/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp011
# ['first_level_conditiononly_1022519/cp011/congruent.nii.gz', 'first_level_conditiononly_1022519/cp011/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp011/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp012
# ['first_level_conditiononly_1022519/cp012/congruent.nii.gz', 'first_level_conditiononly_1022519/cp012/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp012/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp013
# ['first_level_conditiononly_1022519/cp013/congruent.nii.gz', 'first_level_conditiononly_1022519/cp013/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp013/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp014
# ['first_level_conditiononly_1022519/cp014/congruent.nii.gz', 'first_level_conditiononly_1022519/cp014/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp014/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp015
# ['first_level_conditiononly_1022519/cp015/congruent.nii.gz', 'first_level_conditiononly_1022519/cp015/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp015/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp016
# ['first_level_conditiononly_1022519/cp016/congruent.nii.gz', 'first_level_conditiononly_1022519/cp016/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp016/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp017
# ['first_level_conditiononly_1022519/cp017/congruent.nii.gz', 'first_level_conditiononly_1022519/cp017/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp017/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp018
# ['first_level_conditiononly_1022519/cp018/congruent.nii.gz', 'first_level_conditiononly_1022519/cp018/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp018/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp019
# ['first_level_conditiononly_1022519/cp019/congruent.nii.gz', 'first_level_conditiononly_1022519/cp019/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp019/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp020
# ['first_level_conditiononly_1022519/cp020/congruent.nii.gz', 'first_level_conditiononly_1022519/cp020/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp020/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp021
# ['first_level_conditiononly_1022519/cp021/congruent.nii.gz', 'first_level_conditiononly_1022519/cp021/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp021/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp022
# ['first_level_conditiononly_1022519/cp022/congruent.nii.gz', 'first_level_conditiononly_1022519/cp022/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp022/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp023
# ['first_level_conditiononly_1022519/cp023/congruent.nii.gz', 'first_level_conditiononly_1022519/cp023/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp023/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp024
# ['first_level_conditiononly_1022519/cp024/congruent.nii.gz', 'first_level_conditiononly_1022519/cp024/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp024/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp025
# ['first_level_conditiononly_1022519/cp025/congruent.nii.gz', 'first_level_conditiononly_1022519/cp025/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp025/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp026
# ['first_level_conditiononly_1022519/cp026/congruent.nii.gz', 'first_level_conditiononly_1022519/cp026/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp026/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp027
# ['first_level_conditiononly_1022519/cp027/congruent.nii.gz', 'first_level_conditiononly_1022519/cp027/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp027/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp028
# ['first_level_conditiononly_1022519/cp028/congruent.nii.gz', 'first_level_conditiononly_1022519/cp028/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp028/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp029
# ['first_level_conditiononly_1022519/cp029/congruent.nii.gz', 'first_level_conditiononly_1022519/cp029/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp029/noprime.nii.gz']
# loading brains
# calculating_distance
# first_level_conditiononly_1022519/cp030
# ['first_level_conditiononly_1022519/cp030/congruent.nii.gz', 'first_level_conditiononly_1022519/cp030/incongruent.nii.gz', 'first_level_conditiononly_1022519/cp030/noprime.nii.gz']
# loading brains
# calculating_distance

# %%
averaged_scores = summed_scores/len(distance)

avg_adjacency = Adjacency(averaged_scores)
avg_adjacency.labels = condition_labels
fig = avg_adjacency.plot()

# %%
avg_adjacency.data
# Out:
# array([0.300139  , 0.26761334, 0.27239276])

# %%
dmn_distance
# Out:
# []

# %%
file_list
# Out:
# ['first_level_conditiononly_1022519/cp001/congruent.nii.gz',
#  'first_level_conditiononly_1022519/cp001/incongruent.nii.gz',
#  'first_level_conditiononly_1022519/cp001/noprime.nii.gz']
